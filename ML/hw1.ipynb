# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('housing.csv')

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('MEDV', axis = 1), 
                                                    df['MEDV'], 
                                                    test_size = 0.2,
                                                    random_state = 500)

# %%
model = LinearRegression()

# %%
pred = model.fit(X_train,y_train).predict(df.drop('MEDV', axis = 1))

# %%
df['predict'] = pred.round(1)

# %%
df[['MEDV','predict']]
# Out:
#      MEDV  predict
# 0    24.0     29.4
# 1    21.6     24.9
# 2    34.7     30.8
# 3    33.4     28.9
# 4    36.2     28.5
# 5    28.7     25.1
# 6    22.9     22.9
# 7    27.1     19.9
# 8    16.5     12.5
# 9    18.9     19.2
# 10   15.0     19.8
# 11   18.9     21.4
# 12   21.7     21.4
# 13   20.4     19.5
# 14   18.2     19.1
# 15   19.9     19.2
# 16   23.1     20.7
# 17   17.5     17.2
# 18   20.2     16.1
# 19   18.2     18.2
# 20   13.6     12.7
# 21   19.6     17.7
# 22   15.2     16.5
# 23   14.5     14.2
# 24   15.6     15.9
# 25   13.9     13.3
# 26   16.6     15.5
# 27   14.8     15.1
# 28   18.4     19.9
# 29   21.0     21.3
# ..    ...      ...
# 476  16.7     20.2
# 477  12.0     11.0
# 478  14.6     18.6
# 479  21.4     21.0
# 480  23.0     22.5
# 481  23.7     26.1
# 482  25.0     27.7
# 483  21.8     20.1
# 484  20.6     18.9
# 485  21.2     21.7
# 486  19.1     19.0
# 487  20.6     20.4
# 488  15.2     12.1
# 489   7.0      8.9
# 490   8.1      4.7
# 491  13.6     14.4
# 492  20.1     16.4
# 493  21.8     20.3
# 494  24.5     20.9
# 495  23.1     17.6
# 496  19.7     14.2
# 497  18.3     19.0
# 498  21.2     21.2
# 499  17.5     18.1
# 500  16.8     20.3
# 501  22.4     24.0
# 502  20.6     22.2
# 503  23.9     27.6
# 504  22.0     26.1
# 505  11.9     22.0
#
# [506 rows x 2 columns]
