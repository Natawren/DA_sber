# %% [markdown]
# # Практика

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math
# %matplotlib inline
# Out:
# /home/natawren/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## ЦПТ для различных распределений
# Возьмите то непрерывное распределение, которое вам больше всего понравится из списка доступных в модуле [scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html).

# %% [markdown]
# ### Сгенерируйте примеры из распределения

# %%
# ваш код тут
# например вот такое распределение https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.cosine.html#scipy.stats.cosine
laplace_rv = sts.laplace()
sample = laplace_rv.rvs(100)
sample
# Out:
# array([ 1.02329520e-02,  5.44103966e-01,  8.47504461e-01, -9.23793769e-01,
#         6.44328034e-01, -2.93088720e+00,  2.87918157e+00, -1.28001162e+00,
#        -1.36948990e+00,  1.80192597e-01, -1.16119787e+00,  7.87130461e-01,
#        -1.21726402e-01, -4.36868254e-01, -8.41372687e-01, -3.99333213e+00,
#        -2.27187233e+00,  9.52254998e-02, -5.08864361e-01,  4.58705436e+00,
#        -1.76972343e+00,  2.59709459e+00, -1.29459999e-01,  6.28538849e-01,
#        -1.55055615e-02, -2.75493956e+00, -2.53030908e-01,  2.58327591e+00,
#         2.74436331e+00, -1.59113009e+00,  7.31406857e-01,  2.15894322e-01,
#         3.05228628e-02,  1.04179732e+00, -5.61272326e+00, -4.95313646e-01,
#         1.96656421e+00,  6.83654582e-01, -1.67048149e+00, -1.82887710e+00,
#        -7.39293684e-01,  9.81409652e-01, -1.58134929e-01,  7.16168062e-01,
#         2.75812734e-01, -1.04056727e+00,  2.51092120e-01,  1.84623538e+00,
# ...

# %%
sample.dtype

# %%
real_mean = laplace_rv.mean() # настоящее среднее случайной величины

# %%
real_var = laplace_rv.var() # настоящая дисперсия случайной величины

# %% [markdown]
# ### Постройте гистограмму выборки и теоретическую плотность распределения

# %%
# ваш код тут
plt.hist(sample, density=True)
x = np.linspace(-5,5,100)
pdf = laplace_rv.pdf(x)
plt.plot(x, pdf, label='теоретическая плотность', alpha=0.5)
plt.legend()

# %%
sample_mean = sample.mean() # выборочное среднее
print(sample_mean)
sample_var = sample.var() # выборочная дисперсия
print(sample_var)
# Out:
# -0.02769890290849955
# 2.816053601425172

# %% [markdown]
# ### Оценим распределение выборочного среднего для разных объёмов выборок
# Для этого постройте на одном полотне гистограмму выборочных средних и теоретическое распределение выборочных средних по ЦПТ для разных объёмов выборок.
#
# Для теоретического распределение используйте настоящие значения мат ожидания и дисперсии (не приближенные на основе выборки).

# %%
# ваш код тут
    
plt.figure(figsize=(16,9))
x = np.linspace(-1.5,1.5, 10000)
pdf = laplace_rv.pdf(x)

plt.plot(x, pdf, alpha=0.5)
# сгенерируем много выборочных средних
for N in [10, 100,1000, 10000]:
    means = []
    for i in range(1000):
        means.append(np.mean(laplace_rv.rvs(N)))
    plt.hist(means, alpha=0.5, density=True)        
plt.legend(['10', '100', '1000', '10000'])
plt.show()

# %% [markdown]
# Как вы считаете, для выбранного распределения апроксимация распределения выборочного среднего работает хорошо или плохо?
# **Ваш ответ:** работает плохо, так как не следует выбранному распределению

# %% [markdown]
# ## Доверительный интервал на основе ЦПТ
# Возьмите данные для оттока телеком компании, и постройте доверительные интервалы для среднего значения total day calls, используя центральную предельную теорему в разбиении по колонке churn (ушел/не ушел).
#
# Для оценки дисперсии используйте несмещенную оценку (параметр ddof=1).
#
# Сделайте оценку с использованием явной формулы для z интервала, а затем с помощью функций
# `from statsmodels.stats.weightstats import _zconfint_generic`. Сравните результаты.
#
#
# Ссылка на данные: https://drive.google.com/file/d/1X_drKqoarnU2Sz2har7uSCsgyhh8Xtz8/view?usp=sharing

# %%
# либо загружаем из альтернативного хранилища
url ="https://raw.githubusercontent.com/piton1/DA/Lesson_12/telecom_churn.csv"
df=pd.read_csv(url)
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4baddfc73c51> in <module>
#       1 # либо загружаем из альтернативного хранилища
#       2 url ="https://raw.githubusercontent.com/piton1/DA/Lesson_12/telecom_churn.csv"
# ----> 3 df=pd.read_csv(url)
#       4 display(df)
#
# NameError: name 'pd' is not defined

# %%
# df=pd.read_csv('telecom_churn.csv')
# display(df)
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df_new = df[['total day calls', 'churn']].copy()

# %%
df_new
# Out:
#       total day calls  churn
# 0                 110  False
# 1                 123  False
# 2                 114  False
# 3                  71  False
# 4                 113  False
# 5                  98  False
# 6                  88  False
# 7                  79  False
# 8                  97  False
# 9                  84  False
# 10                137   True
# 11                127  False
# 12                 96  False
# 13                 88  False
# 14                 70  False
# 15                 67   True
# 16                139  False
# 17                114  False
# 18                 66  False
# 19                 90  False
# 20                117  False
# 21                 89   True
# 22                112  False
# 23                103  False
# 24                 86  False
# 25                 76  False
# 26                115  False
# 27                 73  False
# 28                109  False
# 29                117  False
# ...               ...    ...
# ...

# %%
data_false = df_new[df_new.churn== False]['total day calls']

N = len(data_false)
print("Доверительный интервал для среднего по цпт неушедших клиентов: [{}, {}] ".format(
    np.mean(data_false) - 2 * np.std(data_false.tolist(), ddof = 1) / np.sqrt(N), np.mean(data_false) + 2 * np.std(data_false.tolist(), ddof = 1) / np.sqrt(N) 
))
# Out:
# Доверительный интервал для среднего по цпт неушедших клиентов: [99.54133858857833, 101.02497720089536]

# %%
data_true = df_new[df_new.churn]['total day calls']

N = len(data_true)
print("Доверительный интервал для среднего по цпт ушедших клиентов: [{}, {}] ".format(
    np.mean(data_true) - 2 * np.std(data_true.tolist(), ddof = 1) / np.sqrt(N), np.mean(data_true) + 2 * np.std(data_true.tolist(), ddof = 1) / np.sqrt(N) 
))
# Out:
# Доверительный интервал для среднего по цпт ушедших клиентов: [99.37134576363385, 103.2994616897823]

# %%
from statsmodels.stats.weightstats import _zconfint_generic
# Out:
# /home/natawren/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
N = len(data_false)
print("Доверительный интервал(расчет с помощью функции) для среднего по цпт неушедших клиентов: \n",
      _zconfint_generic(np.mean(data_false), 
                  np.std(data_false.tolist(), ddof = 1) / np.sqrt(N), 
                  0.05, 'two-sided'))
# Out:
# Доверительный интервал(расчет с помощью функции) для среднего по цпт неушедших клиентов:
#  (99.55618833318324, 101.01012745629045)

# %%
N = len(data_true)

print("Доверительный интервал(расчет с помощью функции)  для среднего по цпт ушедших клиентов: \n",
      _zconfint_generic(np.mean(data_true), 
                  np.std(data_true.tolist(), ddof = 1) / np.sqrt(N), 
                  0.05, 'two-sided'))
# Out:
# Доверительный интервал(расчет с помощью функции)  для среднего по цпт ушедших клиентов:
#  (99.41066229112079, 103.26014516229537)

# %% [markdown]
# Результаты, расчитанные вручную и при помощи функции библиотеки statsmodels схожи, различия незначительные.
